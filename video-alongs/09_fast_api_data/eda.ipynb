# %%
import pandas as pd

df = pd.read_csv("Sales.csv", parse_dates=True, index_col=0).sort_values(by="Date")
df.head()
# Out:
#             Day    Month  Year  Customer_Age             Age_Group  \
# Date
# 2011-01-01    1  January  2011            42        Adults (35-64)
# 2011-01-01    1  January  2011            33  Young Adults (25-34)
# 2011-01-01    1  January  2011            17           Youth (<25)
# 2011-01-01    1  January  2011            39        Adults (35-64)
# 2011-01-01    1  January  2011            23           Youth (<25)
#
#            Customer_Gender        Country             State Product_Category  \
# Date
# 2011-01-01               M  United States        California            Bikes
# 2011-01-01               F         France           Yveline            Bikes
# 2011-01-01               M         Canada  British Columbia            Bikes
# 2011-01-01               M  United States        Washington            Bikes
# 2011-01-01               M      Australia          Victoria            Bikes
#
#               Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# ...

# %%
df.shape, df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 113036 entries, 2013-11-26 to 2016-03-04
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Day               113036 non-null  int64
#  1   Month             113036 non-null  object
#  2   Year              113036 non-null  int64
#  3   Customer_Age      113036 non-null  int64
#  4   Age_Group         113036 non-null  object
#  5   Customer_Gender   113036 non-null  object
#  6   Country           113036 non-null  object
#  7   State             113036 non-null  object
#  8   Product_Category  113036 non-null  object
#  9   Sub_Category      113036 non-null  object
#  10  Product           113036 non-null  object
#  11  Order_Quantity    113036 non-null  int64
#  12  Unit_Cost         113036 non-null  int64
#  13  Unit_Price        113036 non-null  int64
#  14  Profit            113036 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                    count         mean          std     min     25%     50%  \
# Day             113036.0    15.665753     8.781567     1.0     8.0    16.0
# Year            113036.0  2014.401739     1.272510  2011.0  2013.0  2014.0
# Customer_Age    113036.0    35.919212    11.021936    17.0    28.0    35.0
# Order_Quantity  113036.0    11.901660     9.561857     1.0     2.0    10.0
# Unit_Cost       113036.0   267.296366   549.835483     1.0     2.0     9.0
# Unit_Price      113036.0   452.938427   922.071219     2.0     5.0    24.0
# Profit          113036.0   285.051665   453.887443   -30.0    29.0   101.0
# Cost            113036.0   469.318695   884.866118     1.0    28.0   108.0
# Revenue         113036.0   754.370360  1309.094674     2.0    63.0   223.0
#
#                    75%      max
# Day               23.0     31.0
# Year            2016.0   2016.0
# Customer_Age      43.0     87.0
# Order_Quantity    20.0     32.0
# Unit_Cost         42.0   2171.0
# ...

# %%
df.loc["2014"].head()
# Out:
#             Day     Month  Year  Customer_Age             Age_Group  \
# Date
# 2014-03-23   23     March  2014            49        Adults (35-64)
# 2014-05-15   15       May  2014            47        Adults (35-64)
# 2014-05-22   22       May  2014            47        Adults (35-64)
# 2014-02-22   22  February  2014            35        Adults (35-64)
# 2014-01-22   22   January  2014            29  Young Adults (25-34)
#
#            Customer_Gender    Country             State Product_Category  \
# Date
# 2014-03-23               M  Australia   New South Wales      Accessories
# 2014-05-15               F  Australia   New South Wales      Accessories
# 2014-05-22               F  Australia          Victoria      Accessories
# 2014-02-22               M  Australia          Victoria      Accessories
# 2014-01-22               M     Canada  British Columbia      Accessories
#
#            Sub_Category              Product  Order_Quantity  Unit_Cost  \
# Date
# ...

# %%
df["State"].value_counts().reset_index().head()
# Out:
#               State  count
# 0        California  22450
# 1  British Columbia  14116
# 2           England  13620
# 3        Washington  11264
# 4   New South Wales  10412

# %%
df["Country"].value_counts().to_json()
# Out:
# '{"United States":39206,"Australia":23936,"Canada":14178,"United Kingdom":13620,"Germany":11098,"France":10998}'

# %%
import duckdb 
duckdb.query(""" 
            SELECT Country, sum(Profit) as profit
            from df 
            group by country
            order by profit desc
            """).df().to_json()
# Out:
# '{"Country":{"0":"United States","1":"Australia","2":"United Kingdom","3":"Canada","4":"Germany","5":"France"},"profit":{"0":11073644.0,"1":6776030.0,"2":4413853.0,"3":3717296.0,"4":3359995.0,"5":2880282.0}}'
