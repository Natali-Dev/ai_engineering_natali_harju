# %% [markdown]
# # Exercise 4 - FastAPI
#
# In this exercise, you get to work with fastapi to create APIs of different kinds. You'll get to know the simple patterns of CRUD in fastapi. Also you'll learn how to serve csv data, and serve machine learning models.
# - CRUD = Create, Read, Update, Delete
# ## 0. FastAPI glossary API
#
# Read the data from this repository called `fastapi_glossary.json`. Create Pydantic model(s) of the data in a separate script called `data_processing.py`.
#
# a) Now create an endpoint `/glossary` which will return all words and their meaning.
#
# b) Create a query parameter to filter out a specific word
#
# c) Turn your API into a CRUD API, so that you can add glossary, update and delete glossary.
#
# d) Test out your API in Swagger UI.
#
# e) Test out your API using requests inside of a Jupyter notebook or a separate Python script. Try the different request types.

# %% [markdown]
# Read the data from this repository called `fastapi_glossary.json`. Create Pydantic model(s) of the data in a separate script called `data_processing.py`.

# %%
import requests

response = requests.delete("http://127.0.0.1:8000/glossary/delete_word/3")
response.text
# Out:
# 'null'

# %%
response = requests.get("http://127.0.0.1:8000/glossary")
response.text
# Out:
# '[{"id":4,"word":"request body","meaning":"Data sent with POST/PUT/PATCH requests, usually JSON."},{"id":5,"word":"uvicorn","meaning":"ASGI web server used to run FastAPI apps. Command: uvicorn main:app"},{"id":6,"word":"%20","meaning":"URL-encoded space character used in URL paths and query strings."},{"id":7,"word":"Field (pydantic)","meaning":"Function to add metadata and validation constraints to model fields (defaults, rules, descriptions, etc.)."},{"id":8,"word":"DTO","meaning":"Data Transfer Objectâ€”an object that carries data between processes (e.g., client to server via an API)."},{"id":9,"word":"client","meaning":"Program or device that makes requests to a server (e.g., a browser sending HTTP requests and handling responses)."},{"id":10,"word":"schema","meaning":"Structured blueprint defining data organization, types, and rules; a contract for predictable data."},{"id":11,"word":"Depends()","meaning":"FastAPI dependency injection tool to provide request-ready objects to route handlers."},{"id":12,"word":"payload","meaning":"The actual data carried in an API request or response."},{"id":13,"word":"field_validator (pydantic)","meaning":"Custom function for per-field validation beyond basic type checks."},{"id":14,"word":"model_validator","meaning":"Validator that runs on the entire model, with access to multiple fields at once."}]'
